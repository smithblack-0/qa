# %%
# Out:
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\New_Adult\Lana.txt
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\New_Adult\Lana.txt
# valid
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\Romance\u3278.txt
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\New_Adult\Collision_Course.txt
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\Fantasy\u3419.txt
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\Fantasy\u3432.txt
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\Fantasy\u3427.txt
# get
# C:\Users\chris\PycharmProjects\fastai\Data\lambada-dataset\train-novels\Fantasy\u3085.txt
# get
# ...
